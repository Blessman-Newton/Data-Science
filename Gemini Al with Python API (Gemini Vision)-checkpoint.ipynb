# %%
import google.generativeai as genai

# %%
api_key = 'API HERE'

# %%
genai.configure(api_key=api_key)

# %%
for model in genai.list_models():
    print(model.name)
# Out:
# models/chat-bison-001
# models/text-bison-001
# models/embedding-gecko-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro
# models/gemini-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash
# models/embedding-001
# models/text-embedding-004
# models/aqa

# %%
model = genai.GenerativeModel('gemini-1.5-flash')

# %%
#!pip install Pillow

# %%
from PIL import Image
img = PIL.Image.open('ai.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=762x1016>

# %%
response = model.generate_content(img)
# Out:
# '## ALLUVIAL AND OCEAN MINING\n\n**QUESTION 6**\n\nMN 274 2B                             MINI PROJECT\n\nObjective: Innovate ocean mining techniques that minimise environmental damage. \n\nTasks: Research and design equipment and methods that reduce seabed disturbance and water pollution. \n\n**INSTRUCTIONS**\n\nResearch and Data Collection: Conduct fieldwork, laboratory analysis, and literature reviews.\n\nProject Reports: Each group should prepare a detailed report and presentation on their findings and recommendations.\n\nEvaluation: Projects will be evaluated based on originality, feasibility, environmental impact, and potential for implementation.'

# %%
text_prompt = 'generate a research paper per the information above'
response = model.generate_content(contents=[text_prompt, img])

# %%
print(response.text)
# Out:
# ## Research Paper: Innovative Ocean Mining Techniques for Minimizing Environmental Damage
#
# **Abstract:**
#
# This research paper focuses on the critical need to innovate ocean mining techniques to minimize environmental damage. The research will delve into the existing practices of ocean mining, their impact on the marine ecosystem, and analyze the challenges associated with environmental conservation. The paper will then explore various innovative technologies and approaches for responsible ocean mining, focusing on reducing seabed disturbance, mitigating water pollution, and minimizing overall environmental impact. It will also evaluate the feasibility, practicality, and potential for implementation of these innovative techniques in the context of sustainable development and responsible resource extraction.
#
# **Introduction:**
#
# Ocean mining, the process of extracting mineral resources from the seabed, is a rapidly growing industry driven by increasing demand for critical minerals. However, this industry poses significant threats to the fragile marine ecosystem. The current methods employed often result in substantial damage to marine habitats, disrupt the delicate balance of marine life, and contribute to water pollution. Therefore, it becomes imperative to explore and implement innovative ocean mining techniques that minimize environmental impact.
#
# **Literature Review:**
#
# This section will review existing research on the environmental impact of ocean mining, specifically examining the following aspects:
#
# * **Impact on marine biodiversity:** The disruption of benthic communities, habitat loss, and the release of pollutants can significantly impact marine biodiversity.
# * **Seabed disturbance:** The physical disturbance caused by mining activities can alter seabed morphology, impact sediment dynamics, and negatively affect marine life.
# * **Water pollution:** The release of mining waste and chemicals can contaminate the surrounding water, harming marine organisms and impacting the food web.
#
# Furthermore, this section will analyze various technologies and approaches currently being explored to mitigate these impacts:
#
# * **Remotely Operated Vehicles (ROVs):** Using ROVs for underwater operations can minimize physical contact with the seabed and reduce disturbance.
# * **Environmental monitoring and assessment:** Utilizing advanced monitoring technologies and environmental impact assessments can help track and minimize potential risks.
# * **Selective mining techniques:** Focusing on extracting specific resources while minimizing the impact on surrounding areas can be crucial for reducing habitat disruption.
# * **Remediation and restoration strategies:** Implementing effective post-mining remediation and restoration techniques can help mitigate the long-term environmental effects of mining activities.
#
# **Methodology:**
#
# This research will utilize a combination of qualitative and quantitative research methods to explore and analyze innovative ocean mining techniques:
#
# * **Data collection:** This will involve gathering data from existing research papers, scientific reports, industry publications, and case studies.
# * **Fieldwork:** This may include conducting site visits to observe ongoing mining operations, examining the environmental impact, and gathering data on the effectiveness of innovative techniques.
# * **Laboratory analysis:** This may involve analyzing samples of marine sediment, water, and biological specimens to assess the impact of mining activities and the effectiveness of mitigation strategies.
# * **Modeling and simulations:** This will utilize computer models and simulations to assess the potential impact of various mining techniques and evaluate the feasibility and efficiency of proposed solutions.
#
# **Results and Discussion:**
#
# This section will present the findings of the research, analyzing the effectiveness of innovative ocean mining techniques and their potential for minimizing environmental damage. It will evaluate the feasibility, practicality, and potential for implementation of these techniques in the context of sustainable development. This section will also critically discuss the challenges and limitations associated with implementing these innovative solutions, including technological advancements, economic considerations, and policy implications.
#
# **Conclusions and Recommendations:**
#
# This section will summarize the key findings of the research, emphasizing the importance of adopting innovative ocean mining techniques to minimize environmental damage. It will highlight the potential benefits of these techniques, such as reduced impact on marine ecosystems, enhanced resource sustainability, and positive economic implications. The paper will conclude with specific recommendations for stakeholders, including government agencies, mining companies, and research institutions, on promoting responsible ocean mining practices and investing in research and development of innovative technologies.
#
# **References:**
#
# This section will include a comprehensive list of all the sources cited in the research paper.
#
# **Acknowledgements:**
#
# This section will acknowledge any individuals or organizations that have contributed to the research project, including funding bodies, mentors, collaborators, and reviewers.
#
# **Appendices:**
#
# This section may include additional information, such as detailed data tables, figures, diagrams, or technical descriptions of the innovative ocean mining techniques explored in the research.
#
# This proposed structure provides a framework for a comprehensive research paper on innovative ocean mining techniques for minimizing environmental damage. The specific content and findings will depend on the data collected and analysis conducted during the research process. However, the paper aims to contribute to the ongoing discussion on responsible resource extraction and sustainable development in the context of the growing ocean mining industry.
